# %% [markdown]
# <h1 style="color: red;">PART 1 (Input the data and converting)</h1>

# %% [markdown]
# # Step 1 - Import Panda and read data (csv file)

# %%
import pandas as pd

# %%
data = pd.read_csv('C:/Users/Acer/data_folder/blood_inventory_ABneg.csv')
print(data.dtypes)
# Out:
# Month    object
# AB-       int64
# dtype: object

# %% [markdown]
# # Step 2 - Check for result, if object/string convert to datetime format

# %%
data['Month'] = pd.to_datetime(data['Month'], format='%m/%d/%Y')

# %% [markdown]
# # Step 3 - Set the data.set to index (Month)

# %%
data.set_index('Month', inplace=True, drop=False)

# %%
data = data.asfreq('MS')

# %% [markdown]
# # Step 4 - Confirm conversion by printing

# %%
print(data.dtypes)
# Out:
# Month    datetime64[ns]
# AB-               int64
# dtype: object

# %% [markdown]
# <h1 style="color: red;">PART 2 (Visualizing the data)</h1>

# %% [markdown]
# # Step 1 - Use matplot and plot the data

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12, 6))
plt.plot(data.index, data['AB-'], marker='o', label='AB- Blood Requests')
plt.title('3 Years Historical Record of AB+ Blood Requests Handover')
plt.xlabel('Date')
plt.ylabel('Number of Handover')
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()  # Adjust plot for better fit
plt.show()

# %% [markdown]
# <h1 style="color: red;">PART 3 (Choosing the right model of ARIMA)</h1>

# %% [markdown]
# # Method 1 - User plot_acf and plot_pacf (if the lags is not accepted adjust)

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# Plot ACF and PACF with fewer lags
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plot_acf(data['AB-'], ax=plt.gca(), lags=12)  # Adjust lags to 8
plt.title('ACF Plot')

plt.subplot(1, 2, 2)
plot_pacf(data['AB-'], ax=plt.gca(), lags=12)  # Adjust lags to 8
plt.title('PACF Plot')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Method 2 - Check for ADF test if the plot is non-stationary

# %%
from statsmodels.tsa.stattools import adfuller

# Perform ADF test
result = adfuller(data['AB-'])
print('ADF Statistic:', result[0])
print('p-value:', result[1])
print('Critical Values:')
for key, value in result[4].items():
    print(f'{key}: {value}')

# Check if the series is stationary
if result[1] < 0.05:
    print("The time series is stationary.")
else:
    print("The time series is not stationary.")
# Out:
# ADF Statistic: -6.054635529561658
# p-value: 1.253669114373748e-07
# Critical Values:
# 1%: -3.626651907578875
# 5%: -2.9459512825788754
# 10%: -2.6116707716049383
# The time series is stationary.

# %% [markdown]
# # Step 1 - Fit proper ARIMA Model (SARIMA if Seasonal Data)

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# Define your parameters here (adjust them based on your analysis)
p = 2   # Auto-regressive order
d = 0   # Differencing order
q = 0   # Moving average order
P = 0   # Seasonal auto-regressive order
D = 0   # Seasonal differencing order
Q = 0   # Seasonal moving average order
S = 12  # Length of the seasonal cycle (e.g., 12 for monthly data)

# Fit the SARIMA model
model = SARIMAX(data['AB-'], order=(p, d, q), seasonal_order=(P, D, Q, S))
results = model.fit()

# Print the model summary
print(results.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:                    AB-   No. Observations:                   46
# Model:               SARIMAX(2, 0, 0)   Log Likelihood                 -74.489
# Date:                Mon, 28 Oct 2024   AIC                            154.978
# Time:                        02:42:17   BIC                            160.464
# Sample:                    01-01-2021   HQIC                           157.033
#                          - 10-01-2024
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9287      0.210      4.420      0.000       0.517       1.341
# ar.L2          0.0631      0.203      0.311      0.755      -0.334       0.460
# sigma2         1.3667      0.429      3.182      0.001       0.525       2.208
# ...

# %% [markdown]
# # Step 2 - Check for residuals (ensure that the results resembles white noise)

# %%
import matplotlib.pyplot as plt
import statsmodels.api as sm

# Plot residuals
residuals = results.resid

# Q-Q Plot
sm.qqplot(residuals, line='s')
plt.title('Q-Q Plot of Residuals')
plt.show()

# Residuals Plot
plt.figure(figsize=(10, 5))
plt.plot(residuals)
plt.axhline(0, color='red', linestyle='--', linewidth=1)  # Horizontal line at zero
plt.title('Residuals')
plt.xlabel('Time')
plt.ylabel('Residuals')
plt.show()

# Perform Ljung-Box test
lb_test = sm.stats.acorr_ljungbox(residuals, lags=[1], return_df=True)
print(lb_test)  # Check the structure of lb_test

# Access the p-value correctly
p_value = lb_test['lb_pvalue'].values[0]  # Use .values to get the numpy array
if p_value > 0.05:
    print("The residuals do not show significant autocorrelation (white noise).")
else:
    print("The residuals show significant autocorrelation (not white noise).")
# Out:
#     lb_stat  lb_pvalue
# 1  0.280121   0.596622
# The residuals do not show significant autocorrelation (white noise).

# %% [markdown]
# <h1 style="color: red;">PART 4 (Forecasting Model)</h1>

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd

# Generate forecast for the next 12 months
forecast = results.get_forecast(steps=12)
forecast_df = forecast.summary_frame()

# Create a seamless date range starting right after the last date in the observed data
forecast_index = pd.date_range(start=data.index[-1] + pd.DateOffset(months=1), periods=12, freq='ME')
forecast_df.index = forecast_index

combined_data = pd.concat([data['AB-'], forecast_df['mean']], axis=0)

plt.figure(figsize=(12, 6))
plt.plot(combined_data, label='Observed + Forecast', color='blue', linestyle='-', marker='o')
plt.plot(data['AB-'], label='Observed', color='blue', linestyle='-', marker='o')
plt.plot(forecast_df['mean'], label='Forecast', color='orange', linestyle='--', marker='o')

# Fill confidence interval for the forecasted period
plt.fill_between(forecast_df.index, forecast_df['mean_ci_lower'], forecast_df['mean_ci_upper'], 
                 color='orange', alpha=0.3, label='Forecast Range (Confidence Interval)')

# Format x-axis for monthly labels
plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%b %Y'))
plt.xticks(rotation=45)  # Rotate dates for readability

# Add title, labels, grid, and legend
plt.title('Monthly Observed and Forecasted AB- Blood Handover')
plt.xlabel('Month')
plt.ylabel('AB- Blood Handover')
plt.grid(visible=True, which='major', linestyle='--', linewidth=0.5)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Step 3 - Create a csv file of the prediction

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.statespace.sarimax import SARIMAX

# Step 1: Load and prepare your historical data
# Assume `data` is a DataFrame with your historical time series
data = pd.read_csv('C:/Users/Acer/data_folder/blood_inventory_ABneg.csv', parse_dates=['Month'], index_col='Month')

# Step 2: Fit your SARIMA model
# Define your parameters (adjust as needed)
p, d, q = 2, 0, 0
P, D, Q, S = 0, 0, 0, 12  # Example seasonal parameters
model = SARIMAX(data['AB-'], order=(p, d, q), seasonal_order=(P, D, Q, S))
results = model.fit()

# Step 3: Generate forecasts
forecast_steps = 12  # Number of periods to forecast
forecast = results.get_forecast(steps=forecast_steps)
forecast_df = forecast.summary_frame()

# Create a DataFrame for the forecasted values
forecast_dates = pd.date_range(start=data.index[-1] + pd.DateOffset(months=1), periods=forecast_steps, freq='ME')
forecast_df.index = forecast_dates

# Step 4: Save the forecast to a file with explicit date column
forecast_df['Date'] = forecast_dates  # Add forecast_dates as a column
forecast_df.set_index('Date', inplace=True)  # Set the Date as index
forecast_df.to_csv('forecast_file_AB-.csv')  # Save as CSV with Date as index

# Step 5: Plot observed data with a solid line and forecast data with a dashed line
plt.figure(figsize=(12, 6))
plt.plot(combined_data, label='Observed + Forecast', color='blue', linestyle='-', marker='o')
plt.plot(data['AB-'], label='Observed', color='blue', linestyle='-', marker='o')
plt.plot(forecast_df['mean'], label='Forecast', color='orange', linestyle='--', marker='o')

# Fill confidence interval for the forecasted period
plt.fill_between(forecast_df.index, forecast_df['mean_ci_lower'], forecast_df['mean_ci_upper'], 
                 color='orange', alpha=0.3, label='Forecast Range (Confidence Interval)')

# Format x-axis for monthly labels
plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%b %Y'))
plt.xticks(rotation=45)  # Rotate dates for readability

# Add title, labels, grid, and legend
plt.title('Monthly Observed and Forecasted AB- Blood Handover')
plt.xlabel('Month')
plt.ylabel('AB- Blood Handover')
plt.grid(visible=True, which='major', linestyle='--', linewidth=0.5)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Acer\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\Acer\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %% [markdown]
# # Combined result (AB+ and AB-)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# Step 1: Load the forecast data for A+ and A-
O_plus_forecast = pd.read_csv('forecast_file_AB+.csv', parse_dates=['Date'], index_col='Date')
O_minus_forecast = pd.read_csv('forecast_file_AB-.csv', parse_dates=['Date'], index_col='Date')

# Step 2: Load the observed data for A+ and A-
O_plus_observed = pd.read_csv('C:/Users/Acer/data_folder/blood_inventory_ABpos.csv', parse_dates=['Month'], index_col='Month')
O_minus_observed = pd.read_csv('C:/Users/Acer/data_folder/blood_inventory_ABneg.csv', parse_dates=['Month'], index_col='Month')

# Step 3: Combine the forecast datasets
combined_forecast = pd.merge(O_plus_forecast[['mean', 'mean_ci_lower', 'mean_ci_upper']], 
                              O_minus_forecast[['mean', 'mean_ci_lower', 'mean_ci_upper']], 
                              left_index=True, right_index=True, suffixes=('_AB_plus', '_AB_minus'))

# Step 4: Combine observed data with the forecast data
O_plus_observed = O_plus_observed.rename(columns={'AB+': 'Observed_AB_plus'})
O_minus_observed = O_minus_observed.rename(columns={'AB-': 'Observed_AB_minus'})

# Merge observed data into the combined forecast DataFrame
combined_data = pd.merge(combined_forecast, 
                          O_plus_observed[['Observed_AB_plus']], 
                          left_index=True, right_index=True, how='outer')
combined_data = pd.merge(combined_data, 
                          O_minus_observed[['Observed_AB_minus']], 
                          left_index=True, right_index=True, how='outer')

# Step 5: Concatenate observed and forecast data into a single series for each blood type
combined_data['Combined_AB_plus'] = combined_data['Observed_AB_plus'].combine_first(combined_data['mean_AB_plus'])
combined_data['Combined_AB_minus'] = combined_data['Observed_AB_minus'].combine_first(combined_data['mean_AB_minus'])

# Step 6: Save the combined data to a CSV file
combined_data.to_csv('combined_forecast_file_AB.csv', index=True)

# Step 7: Set the x-axis ticks to show only month-year
plt.figure(figsize=(12, 6))

# Plot combined A+ data
plt.plot(combined_data.index, combined_data['Combined_AB_plus'], label='AB+ Handover (Observed + Forecast)', color='blue', linestyle='-', marker='o')
plt.fill_between(combined_data.index, combined_data['mean_ci_lower_AB_plus'], combined_data['mean_ci_upper_AB_plus'], 
                 color='blue', alpha=0.3, label='AB+ Forecast Range (Confidence Interval)')

# Plot combined A- data
plt.plot(combined_data.index, combined_data['Combined_AB_minus'], label='AB- Handover (Observed + Forecast)', color='orange', linestyle='-', marker='o')
plt.fill_between(combined_data.index, combined_data['mean_ci_lower_AB_minus'], combined_data['mean_ci_upper_AB_minus'], 
                 color='orange', alpha=0.3, label='AB- Forecast Range (Confidence Interval)')

# Format x-axis to show only month-year
plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%b %Y'))
plt.xticks(rotation=45)  # Rotate dates for readability

# Add title, labels, grid, and legend
plt.title('Monthly Forecasted and Observed AB+ and AB- Blood Handover')
plt.xlabel('Date')
plt.ylabel('Blood Handover Count')
plt.grid(visible=True, which='major', linestyle='--', linewidth=0.5)
plt.legend()
plt.tight_layout()
plt.show()
